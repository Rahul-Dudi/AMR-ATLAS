# %%
import pandas as pd
from datasets import load_dataset

# %%
dataset = load_dataset(
    "csv", 
    data_files="hf://datasets/DudiRahul/ATLAS_long_format/test.csv",
    token="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"
)
# Out:
# Generating train split: 363 examples [00:00, 15645.72 examples/s]

# %%
df = dataset['train'].to_pandas()
df.head()
# Out:
#   Antimicrobial  Year  Intermediate  Resistant  Susceptible  Total  \
# 0    Amikacin_I  2004           210        342        11692  12244
# 1    Amikacin_I  2005           278        439        12379  13096
# 2    Amikacin_I  2006           422        867        17004  18293
# 3    Amikacin_I  2007           483       1446        21753  23682
# 4    Amikacin_I  2008           593       1883        19803  22279
#
#    resistantFraction
# 0           2.793205
# 1           3.352169
# 2           4.739518
# 3           6.105903
# 4           8.451905

# %%
dataset = load_dataset(
    "csv", 
    data_files="hf://datasets/DudiRahul/ATLAS_long_format/ Open+Atlas_Reuse_Data.xlsx",
    token="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"
)

# %%
df = dataset['train'].to_pandas()
df.head()

# %%
dataset = load_dataset(
    "csv", 
    data_files="hf://datasets/DudiRahul/ATLAS_long_format/cleaned_data1.csv",
    token="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"
)

# %%
df = dataset['train'].to_pandas()
df.head()

# %%
dataset = load_dataset(
    "csv", 
    data_files="hf://datasets/DudiRahul/ATLAS_long_format/dataset_amoxy.csv",
    token="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"
)

# %%
df = dataset['train'].to_pandas()
df.head()
